# %%
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

pd.options.display.max_columns = 300

import warnings
warnings.filterwarnings("ignore")

# %%
#renewable_electricity_output in the world
df_renewable_elec_output = pd.read_csv("Renewable_electricity_output_t.csv")
df_renewable_elec_output.head(2)
# Out:
#    year  Aruba  Afghanistan  Angola  Albania  Andorra  Arab World  \
# 0  1960    NaN          NaN     NaN      NaN      NaN         NaN
# 1  1961    NaN          NaN     NaN      NaN      NaN         NaN
#
#    United Arab Emirates  Argentina  Armenia  American Samoa  \
# 0                   NaN        NaN      NaN             NaN
# 1                   NaN        NaN      NaN             NaN
#
#    Antigua and Barbuda  Australia  Austria  Azerbaijan  Burundi  Belgium  \
# 0                  NaN        NaN      NaN         NaN      NaN      NaN
# 1                  NaN        NaN      NaN         NaN      NaN      NaN
#
#    Benin  Burkina Faso  Bangladesh  Bulgaria  Bahrain  Bahamas, The  \
# 0    NaN           NaN         NaN       NaN      NaN           NaN
# 1    NaN           NaN         NaN       NaN      NaN           NaN
#
#    Bosnia and Herzegovina  Belarus  Belize  Bermuda  Bolivia  Brazil  \
# 0                     NaN      NaN     NaN      NaN      NaN     NaN
# ...

# %%
df_renewable_elec_output.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Columns: 265 entries, year to Zimbabwe
# dtypes: float64(264), int64(1)
# memory usage: 124.3 KB

# %%
df_renewable_elec_output.shape
# Out:
# (60, 265)

# %%
df_renewable_elec_output.dtypes
# Out:
# year                                                      int64
# Aruba                                                   float64
# Afghanistan                                             float64
# Angola                                                  float64
# Albania                                                 float64
# Andorra                                                 float64
# Arab World                                              float64
# United Arab Emirates                                    float64
# Argentina                                               float64
# Armenia                                                 float64
# American Samoa                                          float64
# Antigua and Barbuda                                     float64
# Australia                                               float64
# Austria                                                 float64
# Azerbaijan                                              float64
# ...

# %%
df_renewable_elec_output.describe()
# Out:
#               year      Aruba  Afghanistan     Angola     Albania     Andorra  \
# count    60.000000  26.000000    26.000000  26.000000   26.000000   26.000000
# mean   1989.500000   3.200434    74.836822  74.064498   96.791078   94.237854
# std      17.464249   6.006543     6.678532  12.602948    3.135692    8.145260
# min    1960.000000   0.000000    67.730496  53.174928   86.407767   75.000000
# 25%    1974.750000   0.000000    69.340210  63.525442   95.402827   88.736676
# 50%    1989.500000   0.000000    72.599760  75.880789   97.405838  100.000000
# 75%    2004.250000   0.000000    78.957080  82.144187   99.664069  100.000000
# max    2019.000000  15.099280    87.176603  93.750000  100.000000  100.000000
#
#        Arab World  United Arab Emirates  Argentina    Armenia  American Samoa  \
# count   26.000000             26.000000  26.000000  26.000000       26.000000
# mean     4.484713              0.022494  34.008767  30.871721        0.115074
# ...

# %%
temp_df = df_renewable_elec_output.copy()
temp_df.head()
# Out:
#    year  Aruba  Afghanistan  Angola  Albania  Andorra  Arab World  \
# 0  1960    NaN          NaN     NaN      NaN      NaN         NaN
# 1  1961    NaN          NaN     NaN      NaN      NaN         NaN
# 2  1962    NaN          NaN     NaN      NaN      NaN         NaN
# 3  1963    NaN          NaN     NaN      NaN      NaN         NaN
# 4  1964    NaN          NaN     NaN      NaN      NaN         NaN
#
#    United Arab Emirates  Argentina  Armenia  American Samoa  \
# 0                   NaN        NaN      NaN             NaN
# 1                   NaN        NaN      NaN             NaN
# 2                   NaN        NaN      NaN             NaN
# 3                   NaN        NaN      NaN             NaN
# 4                   NaN        NaN      NaN             NaN
#
#    Antigua and Barbuda  Australia  Austria  Azerbaijan  Burundi  Belgium  \
# 0                  NaN        NaN      NaN         NaN      NaN      NaN
# ...

# %%
countries=[]
for c in temp_df.columns:
    if c!='year':
        countries.append(c)        
#print (countries)
# Out:
# ['Aruba', 'Afghanistan', 'Angola', 'Albania', 'Andorra', 'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia', 'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The', 'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda', 'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan', 'Botswana', 'Central African Republic', 'Canada', 'Central Europe and the Baltics', 'Switzerland', 'Channel Islands', 'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.', 'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica', 'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands', 'Cyprus', 'Czech Republic', 'Germany', 'Djibouti', 'Dominica', 'Denmark', 'Dominican Republic', 'Algeria', 'East Asia & Pacific (excluding high income)', 'Early-demographic dividend', 'East Asia & Pacific', 'Europe & Central Asia (excluding high income)', 'Europe 
# ...

# %%
plt.figure(figsize=(14, 6))
for c1 in countries:
    temp_df_ = temp_df[[c1, 'year']]
    sns.lineplot(x=temp_df_["year"], y=temp_df_[c1], label=c1)
plt.xlabel("Year")
plt.ylabel("Efficiency") 
plt.title("Efficiency across the years per country")
# Out:
# Text(0.5,1,'Efficiency across the years per country')

# %%
temp_df = df_renewable_elec_output[(1960 < df_renewable_elec_output.year) & (df_renewable_elec_output.year < 2016)]
temp_df = temp_df.drop(columns='year')
temp_df.describe()
# Out:
#            Aruba  Afghanistan     Angola     Albania     Andorra  Arab World  \
# count  26.000000    26.000000  26.000000   26.000000   26.000000   26.000000
# mean    3.200434    74.836822  74.064498   96.791078   94.237854    4.484713
# std     6.006543     6.678532  12.602948    3.135692    8.145260    1.059436
# min     0.000000    67.730496  53.174928   86.407767   75.000000    2.920702
# 25%     0.000000    69.340210  63.525442   95.402827   88.736676    3.759258
# 50%     0.000000    72.599760  75.880789   97.405838  100.000000    4.307227
# 75%     0.000000    78.957080  82.144187   99.664069  100.000000    5.148864
# max    15.099280    87.176603  93.750000  100.000000  100.000000    7.241521
#
#        United Arab Emirates  Argentina    Armenia  American Samoa  \
# count             26.000000  26.000000  26.000000       26.000000
# mean               0.022494  34.008767  30.871721        0.115074
# std                0.068247   4.980156  11.936226        0.277043
# ...

# %%
def plot_by_country(_df, title, nb_col):
    _df = _df.describe().iloc[nb_col, :]
    plt.figure(figsize=(22, 10))
    sns.barplot(x=_df.index, y=_df.values)
    plt.title(title)

# %%
plot_by_country(temp_df, "75% efficiency by country", 6)

# %%
def plot_corr(df_):
    corr = df_.corr()
    corr

    # Generate a mask for the upper triangle
    mask = np.zeros_like(corr, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True

    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=(14, 12))

    # Generate a custom diverging colormap
    #cmap = sns.diverging_palette(220, 10, as_cmap=True)

    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(corr, mask=mask, center=0, square=True, cmap='Spectral', linewidths=.5, cbar_kws={"shrink": .5}) #annot=True

# %%
plot_corr(temp_df)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/statsmodels/nonparametric/kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     454     try:
# --> 455         bw = float(bw)
#     456     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-57-35cb5f08252c> in <module>
#       1 plt.figure(figsize=(14, 9))
#       2 for col in temp_df.columns:
# ----> 3     sns.distplot(temp_df[temp_df[col] != 0][col], label=col, hist=False)
#       4 plt.title("Distribution of the station's efficiency")
#
# ...
